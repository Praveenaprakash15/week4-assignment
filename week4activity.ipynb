# %%
#1.Compare churn count with respect to gender.
import pandas as pd
data=pd.read_excel('/content/sample_data/Telco-Customer-Churn.xlsx')
df=pd.DataFrame(data)
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='gender',data=df,hue='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#2.Find out how many female senior citizens there in the dataset
df=pd.DataFrame(data)
sns.boxplot(y='gender',x='SeniorCitizen',data=df,hue='SeniorCitizen')

# %%
#3.Compare 'tenure' with 'Total Charges'
import pandas as pd
data=pd.read_excel('/content/sample_data/Telco-Customer-Churn.xlsx')
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.DataFrame(data)
sns.scatterplot(x='tenure',y='TotalCharges',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#4.Find out which contract is preferred by the senior citizen.
import pandas as pd
df=pd.DataFrame(data)
sns.countplot(x='Contract',data=df,hue='SeniorCitizen')

# %%
#5.Comment on your finds on Payment Method?
plt.figure()
plt.hist(data['PaymentMethod'],color='red',rwidth=0.5)
plt.xlabel('PaymentMethod')
plt.ylabel('Number of customers')
plt.xticks(rotation=90)
print('Mostly used payment method is Electronic check and it is shown in the graph below.' )
# Out:
# Mostly used payment method is Electronic check and it is shown in the graph below.
